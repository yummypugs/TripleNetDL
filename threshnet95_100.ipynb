# %%
import torch

print(torch.cuda.is_available())
# Out:
# True

# %%
# %run cifar10threshnet\main95.py
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# The model has 16189202 trainable parameters.
#
# ===> epoch: 1/200
# train:
#  500/500 [================================================================================>]  Step: 79ms | Tot: 39s442ms | Loss: 1.3277 | Acc: 51.826% (25913/50000)
# (663.871168255806, 0.51826)
# test:
#  100/100 [================================================================================>]  Step: 23ms | Tot: 2s216ms | Loss: 1.5075 | Acc: 48.780% (4878/10000)
#
# ===> epoch: 2/200
# train:
#  500/500 [================================================================================>]  Step: 79ms | Tot: 39s454ms | Loss: 0.9124 | Acc: 68.356% (34178/50000)
# (456.2048769593239, 0.68356)
# test:
#  100/100 [================================================================================>]  Step: 22ms | Tot: 2s231ms | Loss: 0.9183 | Acc: 68.970% (6897/10000)
#
# ===> epoch: 3/200
# train:
# ...
